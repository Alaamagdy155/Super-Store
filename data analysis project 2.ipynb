# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

file_path = r'C:\Users\FORSAN ZAG\Desktop\Sample - Superstore.csv'
df = pd.read_csv(file_path, encoding='latin1')

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.describe(include='object')
# Out:
#               Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# count             9994       9994        9994            9994        9994
# unique            5009       1237        1334               4         793
# top     CA-2017-100111   9/5/2016  12/16/2015  Standard Class    WB-21850
# freq                14         38          35            5968          37
#
#         Customer Name   Segment        Country           City       State  \
# count            9994      9994           9994           9994        9994
# unique            793         3              1            531          49
# top     William Brown  Consumer  United States  New York City  California
# freq               37      5191           9994            915        2001
#
#        Region       Product ID         Category Sub-Category     Product Name
# count    9994             9994             9994         9994             9994
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.drop(['Row ID' ,'Order ID' , 'Customer ID' ,'Product ID' ,'Postal Code'] , axis=1 , inplace=True)

# %%
df.head()
# Out:
#   Order Date  Ship Date       Ship Mode    Customer Name    Segment  \
# 0 2016-11-08 2016-11-11    Second Class      Claire Gute   Consumer
# 1 2016-11-08 2016-11-11    Second Class      Claire Gute   Consumer
# 2 2016-06-12 2016-06-16    Second Class  Darrin Van Huff  Corporate
# 3 2015-10-11 2015-10-18  Standard Class   Sean O'Donnell   Consumer
# 4 2015-10-11 2015-10-18  Standard Class   Sean O'Donnell   Consumer
#
#          Country             City       State Region         Category  \
# 0  United States        Henderson    Kentucky  South        Furniture
# 1  United States        Henderson    Kentucky  South        Furniture
# 2  United States      Los Angeles  California   West  Office Supplies
# 3  United States  Fort Lauderdale     Florida  South        Furniture
# 4  United States  Fort Lauderdale     Florida  South  Office Supplies
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
df.isnull().sum()
# Out:
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Region           0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
plt.figure(figsize=(13,6))
category_profit = df.groupby('Category')['Profit'].mean()

category_profit.plot(kind='bar', color='skyblue')
plt.title('Distribution of Categories')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(13,6))
category_profit = df.groupby('Category')['Sales'].mean()

category_profit.plot(kind='bar', color='skyblue')
plt.title('Distribution of Categories')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.show()

# %%
sub_category_profit = df.groupby('Sub-Category')['Profit'].mean().sort_values(ascending=False)
sub_category_profit
# Out:
# Sub-Category
# Copiers        817.909190
# Accessories     54.111788
# Phones          50.073938
# Chairs          43.095894
# Appliances      38.922758
# Machines        29.432669
# Envelopes       27.418019
# Storage         25.152277
# Paper           24.856620
# Binders         19.843574
# Labels          15.236962
# Furnishings     13.645918
# Art              8.200737
# Fasteners        4.375660
# Supplies        -6.258418
# Bookcases      -15.230509
# Tables         -55.565771
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(15,6))
sub_category_profit = df.groupby('Sub-Category')['Profit'].mean()

sub_category_profit.plot(kind='bar', color='skyblue')
plt.title('Distribution of Sub Categories')
plt.xlabel('Sub Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
df['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
Cat_Region = df.groupby('Region')['Category'].count()
Cat_Region
# Out:
# Region
# Central    2323
# East       2848
# South      1620
# West       3203
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(20,8))
plt.title('Distribution of Categories Depand on Region' , fontsize=20)
plt.grid()
sns.countplot(data=df , x='Category', hue='Region' )
# Out:
# <AxesSubplot:title={'center':'Distribution of Categories Depand on Region'}, xlabel='Category', ylabel='count'>

# %%
df_p = df.groupby('Segment')['Profit'].mean()
df_p
# Out:
# Segment
# Consumer       25.836873
# Corporate      30.456667
# Home Office    33.818664
# Name: Profit, dtype: float64

# %%
df_p = df.groupby('Segment')['Profit'].mean()
df_p
plt.figure(figsize=(10,5))
df_p.plot(kind='bar')
plt.title('Average Sales by Segment')
plt.xlabel('Segment')
plt.ylabel('Average Sales')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.title('Distribution of  Categories Depand on Segment' , fontsize=20)
sns.countplot(data=df , x='Category', hue='Segment' )
# Out:
# <AxesSubplot:title={'center':'Distribution of  Categories Depand on Segment'}, xlabel='Category', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
plt.title('Distribution of  Categories Depand on Ship mode' , fontsize=20)
sns.countplot(data=df , x='Category', hue='Ship Mode' )
# Out:
# <AxesSubplot:title={'center':'Distribution of  Categories Depand on Ship mode'}, xlabel='Category', ylabel='count'>

# %%
#df['month']=df['Order Date'].dt.month   
#cat_by_month= df.groupby('month')['Profit'].sum()
#cat_by_month

# %%
Cat_Region = df.groupby(['Region']).mean()[['Profit']]
Cat_Region
# Out:
#             Profit
# Region
# Central  17.092709
# East     32.135808
# South    28.857673
# West     33.849032

# %%
plt.figure(figsize=(21,10))
plt.title('Profit Distribution by Region')
myexplode = [0, 0, 0, 0.2]
plt.pie(Cat_Region['Profit'],autopct='%.2f%%', labels=Cat_Region.index, startangle=140, colors=plt.cm.tab10.colors,
        explode = myexplode ,shadow = True )
plt.show()

# %%
cat=df.groupby('Order Date')['Sub-Category'].count().reset_index()
cat
# Out:
#      Order Date  Sub-Category
# 0    2014-01-03             1
# 1    2014-01-04             3
# 2    2014-01-05             1
# 3    2014-01-06             9
# 4    2014-01-07             2
# ...         ...           ...
# 1232 2017-12-26             4
# 1233 2017-12-27             2
# 1234 2017-12-28            19
# 1235 2017-12-29            12
# 1236 2017-12-30             7
#
# [1237 rows x 2 columns]

# %%
df['Profit'] = pd.to_numeric(df['Profit'], errors='coerce')
df['Discount'] = pd.to_numeric(df['Discount'], errors='coerce')

plt.figure(figsize=(12, 6))
plt.scatter(df['Discount'], df['Profit'], alpha=0.6, color='green', label='Profit vs Discount')
plt.title('Relationship Between Profit and Discount', fontsize=16)
plt.xlabel('Discount', fontsize=12)
plt.ylabel('Profit', fontsize=12)
plt.axhline(0, color='red', linestyle='--', linewidth=1)  
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.regplot(data=df, x='Discount', y='Sales', scatter=True, color='purple', line_kws={"color": "red"})
plt.title('Sales vs Discount with Trendline', fontsize=16)
plt.xlabel('Discount', fontsize=12)
plt.ylabel('Sales', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.regplot(data=df, x='Sales', y='Profit', scatter=True, color='orange', line_kws={"color": "red"})
plt.title('Sales vs Profit with Trendline', fontsize=16)
plt.xlabel('Sales', fontsize=12)
plt.ylabel('Profit', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
product_gro = df.groupby(['Product Name']).sum()['Sales']
product_gro.head()
# Out:
# Product Name
# "While you Were Out" Message Book, One Form per Page     25.228
# #10 Gummed Flap White Envelopes, 100/Box                 41.300
# #10 Self-Seal White Envelopes                           108.682
# #10 White Business Envelopes,4 1/8 x 9 1/2              488.904
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                 286.672
# Name: Sales, dtype: float64

# %%
Top_5_Selling = product_gro.sort_values(ascending = False)
Top_5_Selling_product = Top_5_Selling.head()

Top_5_Selling_product
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# Name: Sales, dtype: float64

# %%
Top_5_Selling_product.plot(kind='bar')

plt.title('Top 5 Selling products' , fontsize=15)
plt.xlabel('product')
plt.ylabel('Total profit')
plt.legend('Sales')
plt.show()

# %%
product_gro = df.groupby(['Product Name']).sum()['Profit']
Top_5_profit = product_gro.sort_values(ascending = False)
Top_5_profity_product = Top_5_profit.head()

# %%
Top_5_profity_product.plot(kind='bar')
plt.title('Top 5 profity products' , fontsize=15)
plt.xlabel('product')
plt.ylabel('Total profit')
plt.legend('profit')
plt.show()

# %%
Top_5_profity_product.index ==Top_5_Selling_product.index
# Out:
# array([ True,  True, False, False, False])

# %%
fig,(ax1,ax2)= plt.subplots(1,2, figsize=(15,5))

Top_5_Selling_product.plot(kind='bar' , y='Sales' , ax=ax1)
ax1.set_title('Top 5 Selling product')

Top_5_profity_product.plot(kind='bar' , y='Profit' , ax=ax2)
ax2.set_title('Top 5 profit product')

plt.show()

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
product= df[df['Product Name']=='Canon imageCLASS 2200 Advanced Copier']
product
# Out:
#      Order Date  Ship Date       Ship Mode       Customer Name      Segment  \
# 2623 2017-10-22 2017-10-24     First Class        Tom Ashbrook  Home Office
# 4190 2017-11-17 2017-11-22  Standard Class        Hunter Lopez     Consumer
# 6425 2016-05-23 2016-05-27  Standard Class  Christopher Conant     Consumer
# 6826 2016-10-02 2016-10-09  Standard Class        Tamara Chand    Corporate
# 8153 2017-03-23 2017-03-25     First Class        Raymond Buch     Consumer
#
#             Country           City         State   Region    Category  \
# 2623  United States  New York City      New York     East  Technology
# 4190  United States         Newark      Delaware     East  Technology
# 6425  United States   Philadelphia  Pennsylvania     East  Technology
# 6826  United States      Lafayette       Indiana  Central  Technology
# 8153  United States        Seattle    Washington     West  Technology
#
#      Sub-Category                           Product Name      Sales  Quantity  \
# ...

# %%
Res_gro = product.groupby(['Region']).mean()[['Sales' , 'Profit']]
Res_gro
# Out:
#                 Sales     Profit
# Region
# Central  17499.950000  8399.9760
# East     10033.304667  3359.9904
# West     13999.960000  6719.9808

# %%
Res_gro.plot(kind='bar')
plt.show()

# %%
product2= df[df['Product Name']=='Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind']
product2
# Out:
#      Order Date  Ship Date       Ship Mode         Customer Name      Segment  \
# 509  2015-03-16 2015-03-22  Standard Class  Christopher Martinez     Consumer
# 2239 2016-11-15 2016-11-17    Second Class            Toby Gnade     Consumer
# 2846 2017-09-10 2017-09-15  Standard Class          Skye Norling  Home Office
# 5310 2017-11-19 2017-11-21     First Class           Nathan Cano     Consumer
# 7280 2015-02-21 2015-02-27  Standard Class          Pierre Wener     Consumer
# 7683 2015-04-28 2015-05-01     First Class       Shirley Daniels  Home Office
# 8749 2015-06-16 2015-06-19     First Class        Lena Creighton     Consumer
# 8760 2016-01-31 2016-02-06  Standard Class            Ben Ferrer  Home Office
# 8858 2017-10-13 2017-10-20  Standard Class             Jane Waco    Corporate
# 9615 2014-11-11 2014-11-13     First Class             Mary Zewe    Corporate
#
#             Country           City       State   Region         Category  \
# ...

# %%
Res_gro2 = product2.groupby(['Region']).mean()[['Sales' , 'Profit']]
Res_gro2
# Out:
#                Sales     Profit
# Region
# Central  2033.584000  -508.3960
# East     2796.178000  1207.4405
# South    3812.970000  1906.4850
# West     2711.445333  1016.7920

# %%
Res_gro2.plot(kind='bar')
plt.show()

# %%
product2 = df[(df['Product Name']=='Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind') & (df['Region']=='Central')]
product2
# Out:
#      Order Date  Ship Date       Ship Mode    Customer Name      Segment  \
# 2846 2017-09-10 2017-09-15  Standard Class     Skye Norling  Home Office
# 5310 2017-11-19 2017-11-21     First Class      Nathan Cano     Consumer
# 7683 2015-04-28 2015-05-01     First Class  Shirley Daniels  Home Office
#
#             Country     City     State   Region         Category Sub-Category  \
# 2846  United States  Chicago  Illinois  Central  Office Supplies      Binders
# 5310  United States  Houston     Texas  Central  Office Supplies      Binders
# 7683  United States  Midland  Michigan  Central  Office Supplies      Binders
#
#                                            Product Name     Sales  Quantity  \
# 2846  Fellowes PB500 Electric Punch Plastic Comb Bin...   762.594         3
# 5310  Fellowes PB500 Electric Punch Plastic Comb Bin...  1525.188         6
# 7683  Fellowes PB500 Electric Punch Plastic Comb Bin...  3812.970         3
#
#       Discount    Profit
# ...

# %%
product2['Discount'].plot(kind='bar')
plt.show()

# %%
monthly_sales = df.groupby(['Order Date'] ).sum()
monthly_sales


monthly_sales = monthly_sales.resample('M').sum()
plt.figure(figsize=(25,8))
plt.plot(monthly_sales['Sales'])
plt.xlabel("Order Date")
plt.ylabel("Sales")
plt.title("Monthly Sales Trend")
plt.show()

# %%
yearly_sales = monthly_sales.resample('Y').sum() 

plt.figure(figsize=(25,8))
plt.plot(yearly_sales['Sales'])
plt.xlabel("Order Date")
plt.ylabel("Sales")
plt.title("yearly Sales Trend")
plt.show()

# %%
monthly_sales = df.groupby(['Order Date'] ).sum()
monthly_sales

monthly_sales = monthly_sales.resample('M').sum()
plt.figure(figsize=(25,8))
plt.plot(monthly_sales['Profit'])
plt.xlabel("Order Date")
plt.ylabel("Profit")
plt.title("Monthly Profit Trend")
plt.show()

# %%
yearly_sales = monthly_sales.resample('Y').sum() 

plt.figure(figsize=(25,8))
plt.plot(yearly_sales['Profit'])
plt.xlabel("Order Date")
plt.ylabel("Profit")
plt.title("yearly Profit Trend")
plt.show()

# %%
df_places = df[['City','State','Region','Sales','Profit']]
df_places.head()
# Out:
#               City       State Region     Sales    Profit
# 0        Henderson    Kentucky  South  261.9600   41.9136
# 1        Henderson    Kentucky  South  731.9400  219.5820
# 2      Los Angeles  California   West   14.6200    6.8714
# 3  Fort Lauderdale     Florida  South  957.5775 -383.0310
# 4  Fort Lauderdale     Florida  South   22.3680    2.5164

# %%
grouped_data = df_places.groupby(['Region'] , as_index=False).sum()
grouped_data.sort_values(by='Sales' , ascending= False , inplace= True)

plt.figure(figsize=(10,7))
plt.bar(grouped_data['Region'],grouped_data['Sales'])
plt.title('Sales on Region')
plt.xlabel('Region')
plt.ylabel('Sales')
plt.show()

# %%
grouped_data = df_places.groupby(['Region'] , as_index=False).sum()
grouped_data.sort_values(by='Profit' , ascending= False , inplace= True)

plt.figure(figsize=(10,7))
plt.bar(grouped_data['Region'],grouped_data['Profit'])
plt.title('Profit on Region')
plt.xlabel('Region')
plt.ylabel('Profit')
plt.show()

# %%
df['City'].nunique()
# Out:
# 531

# %%
df_city = df[['City' , 'Profit' , 'Sales']]
df_city.head()
# Out:
#               City    Profit     Sales
# 0        Henderson   41.9136  261.9600
# 1        Henderson  219.5820  731.9400
# 2      Los Angeles    6.8714   14.6200
# 3  Fort Lauderdale -383.0310  957.5775
# 4  Fort Lauderdale    2.5164   22.3680

# %%
top_cities = df.groupby('City')['Sales'].sum().sort_values(ascending=False).head(5)
top_cities
# Out:
# City
# New York City    256368.161
# Los Angeles      175851.341
# Seattle          119540.742
# San Francisco    112669.092
# Philadelphia     109077.013
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(8, 6))
top_cities.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Top 5 Cities by Sales', fontsize=16)
plt.xlabel('City', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
top_cities = df.groupby('City')['Profit'].sum().sort_values(ascending=False).head(5)

top_cities
# Out:
# City
# New York City    62036.9837
# Los Angeles      30440.7579
# Seattle          29156.0967
# San Francisco    17507.3854
# Detroit          13181.7908
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(8, 6))
top_cities.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Top 5 Cities by Profit', fontsize=16)
plt.xlabel('City', fontsize=12)
plt.ylabel('Total Profit', fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
df_Dis = df.groupby('Discount')['Sales'].median()           #median outlier 
df_Dis.head()
# Out:
# Discount
# 0.00     53.550
# 0.10    327.780
# 0.15    359.499
# 0.20     51.984
# 0.30    359.058
# Name: Sales, dtype: float64

# %%
df_Dis.plot(kind='bar')
plt.title('Discount for product', fontsize=16)
plt.xlabel('Discount', fontsize=12)
plt.ylabel('Sales', fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
df_Dis = df.groupby('Discount')['Profit'].median()           #median outlier 
df_Dis.head()
# Out:
# Discount
# 0.00    15.9952
# 0.10    54.3240
# 0.15    14.0980
# 0.20     6.4944
# 0.30   -25.3764
# Name: Profit, dtype: float64

# %%
df_Dis.plot(kind='bar')
plt.title('Discount for product', fontsize=16)
plt.xlabel('Discount', fontsize=12)
plt.ylabel('profit', fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
df_r = df.groupby('Region')['City'].unique()
df_r
# Out:
# Region
# Central    [Fort Worth, Madison, Fremont, Houston, Richar...
# East       [Philadelphia, Dover, New York City, Troy, Col...
# South      [Henderson, Fort Lauderdale, Concord, Melbourn...
# West       [Los Angeles, Seattle, West Jordan, San Franci...
# Name: City, dtype: object

# %%
df_r = df.groupby('Category')['Sub-Category'].unique()
df_r
# Out:
# Category
# Furniture                   [Bookcases, Chairs, Tables, Furnishings]
# Office Supplies    [Labels, Storage, Art, Binders, Appliances, Pa...
# Technology                  [Phones, Accessories, Machines, Copiers]
# Name: Sub-Category, dtype: object
